# %% [markdown]
# <a href="https://colab.research.google.com/github/zava2000/Complete-Python-3-Bootcamp/blob/master/proyecto_eco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejemplo para empezar con Github y colab

# %% [markdown]
# Proceso
# 1.   cargar sensores
# 2.   mostrar señales y registrar

# %% [markdown]
# ##Librerias

# %%
import time 
from IPython.display import Image

# %% [markdown]
# https://user-images.githubusercontent.com/54563177/84036943-4a88c800-a974-11ea-82e5-695ea899155c.jpg

# %% [markdown]
# ## Funciones

# %%
def programa_principal():
  '''carga los sensores y devuelve True si esta todo Ok'''
  registrar_valores = False # para avisar si puede procesar datos

  print("chequeando los sensores")

  for i in range(0,11):
  #print(i)
    time.sleep(1)
    print(colored(str(i/10 *100)+" % " , 'red'))

  if i == 10:
    print("listo para registrar")
    registrar_valores = True

  return registrar_valores

# %% [markdown]
# ## Programa Principal

# %%
respuesta = programa_principal()

if  respuesta == True: 
  print(colored("Visualizando y Registrando", 'green'))

else:
   print("visualizando pero NO! está registrando")
  
Image('https://thumbs.gfycat.com/VerifiableWealthyAmericanratsnake.webp', format='png')
# Out:
# chequeando los sensores
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# 100.0 %
# listo para registrar
# Visualizando y Registrando

# %%
from termcolor import colored
